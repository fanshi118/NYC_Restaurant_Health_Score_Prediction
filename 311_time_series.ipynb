# %%
import sys
import csv
import pandas as pd
import numpy as np
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('data/311_DOHMH_Restaurant.csv')
# Out:
# /Users/fancyshmancy/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
df['Created Date'] = pd.to_datetime(df['Created Date']).apply( lambda x: x.date() )

# %%
comp_ts = df[['Created Date','Unique Key']].groupby('Created Date').count()
ax = comp_ts.plot(figsize=(10,10))
